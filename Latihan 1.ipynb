# %%
nik="61120906070xxxxx"
nama="Julio Ronaldi"
tmptgllahir="Pontianak"
gender="Laki-laki"
alamat="""Jl. Karya Komp. Karya Indah III no. A27
        RT/RW    :  052/015
        Kel/Desa :  PAL SEMBILAN
        Kecamatan:  Sungai Kakap"""
agama="Katholik"
statusperkawinan="Belum Kawin"
pekerjaan="Belum/Tidak bekerja"
kewarganegaraan="WNI"
berlakuhingga="Seumur Hidup"

#cetak
print("=============================================================\n")
print('{:>42}'.format("Kartu Tanda Penduduk"))
print("\n=============================================================")
print("NIK              : ", nik)
print("Nama             : ", nama)
print("Tempat/Tgl Lahir : ", tmptgllahir)
print("Jenis Kelamin    : ", gender)
print("Alamat           : ", alamat)
print("Agama            : ", agama)
print("Status Perkawinan: ", statusperkawinan)
print("Perkejaan        : ", pekerjaan)
print("Kewarganegaraan  : ", kewarganegaraan)
print("Berlaku Hingga   : ", berlakuhingga)
print("""
                                                KUBU RAYA
                                                30-01-2020""")
print("=============================================================")
# Out:
# ...
#
#                       Kartu Tanda Penduduk
#
# ...
# NIK              :  61120906070xxxxx
# Nama             :  Julio Ronaldi
# Tempat/Tgl Lahir :  Pontianak
# Jenis Kelamin    :  Laki-laki
# Alamat           :  Jl. Karya Komp. Karya Indah III no. A27
#         RT/RW    :  052/015
#         Kel/Desa :  PAL SEMBILAN
#         Kecamatan:  Sungai Kakap
# Agama            :  Katholik
# Status Perkawinan:  Belum Kawin
# Perkejaan        :  Belum/Tidak bekerja
# Kewarganegaraan  :  WNI
# Berlaku Hingga   :  Seumur Hidup
#
#                                                 KUBU RAYA
#                                                 30-01-2020
# ...

# %%
sim = "Surat Izin Mengemudi"
tipe = "C"
noreg = "1014-0207-0000xx"
ttl = "Pontianak, 06-07-2002"
jeniskel = "--Pria"
nama = "Julio Ronaldi"
alamat = """Komp. Karya Indah III A-27
        PAL SEMBILAN SUNGAI KAKAP"""
status = "Mahasiswa"
prov = "Kalbar"
berlaku = "04-11-2025"

#cetak
print("=============================================================\n")
print ('{:>42}'.format(sim))
print("\n=============================================================")

print('{:>52}'.format(tipe))
print('{:>60}'.format(noreg))


print("1. ", nama)
print("2. ", ttl)
print("3. ", jeniskel)
print("4. ", alamat)
print("5. ", status)
print("6. ", prov)

print('{:>60}'.format(berlaku))
print("=============================================================")
# Out:
# ...
#
#                       Surat Izin Mengemudi
#
# ...
#                                                    C
#                                             1014-0207-0000xx
# 1.  Julio Ronaldi
# 2.  Pontianak, 06-07-2002
# 3.  --Pria
# 4.  Komp. Karya Indah III A-27
#         PAL SEMBILAN SUNGAI KAKAP
# 5.  Mahasiswa
# 6.  Kalbar
#                                                   04-11-2025
# ...

# %%
sip = "1023-0159-000xxx"
biodata ="Curriculum VITAE"
nama="Julio Ronaldi"
gender="Laki-laki"
agama="Khatolik"
ttl="Pontianak, 06-07-2002"
alamat = """Komp. Karya Indah III A-27
                         PAL SEMBILAN
                         KOTA BARU UJUNG"""
pd_terakhir= "S1"
organisasi="KOMINFO"
pengalaman_kerja="Manager di KOMINFO"
prestasi="""- Juara 1 Basket Tingkat SMP
                         - Juara 1 Lomba Vokal Solo
                         - Juara 1 Balap 1000cc
                         - Juara 1 Lomba Desain
                         - Juara 1 Lomba Mobile App Design"""
cv_perusahaan="Curriculum VITAE"

#cetak
print("=============================================================\n")
print ('{:>38}'.format(biodata))
print("\n=============================================================")

print('{:>60}'.format(cv_perusahaan))
print('{:>60}'.format(sip))


print("Nama                  : ", nama)
print("Jenis Kelamin         : ", gender)
print("Agama                 : ", agama)
print("Tempat, Tanggal Lahir : ", ttl)
print("Alamat                : ", alamat)
print("Pendidikan            : ", pd_terakhir)
print("Organisasi            : ", organisasi)
print("Pengalaman Kerja      : ", pengalaman_kerja)
print("Prestasi              : ", prestasi)

print("\n=============================================================")
# Out:
# ...
#
#                       Curriculum VITAE
#
# ...
#                                             Curriculum VITAE
#                                             1023-0159-000xxx
# Nama                  :  Julio Ronaldi
# Jenis Kelamin         :  Laki-laki
# Agama                 :  Khatolik
# Tempat, Tanggal Lahir :  Pontianak, 06-07-2002
# Alamat                :  Komp. Karya Indah III A-27
#                          PAL SEMBILAN
#                          KOTA BARU UJUNG
# Pendidikan            :  S1
# Organisasi            :  KOMINFO
# Pengalaman Kerja      :  Manager di KOMINFO
# Prestasi              :  - Juara 1 Basket Tingkat SMP
#                          - Juara 1 Lomba Vokal Solo
#                          - Juara 1 Balap 1000cc
#                          - Juara 1 Lomba Desain
#                          - Juara 1 Lomba Mobile App Design
#
# ...
